# %%
import pandas as pd

# %%
vc = pd.read_csv("country_vaccination_stats.csv")
vc
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 NaN
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
vc["daily_vaccinations"].fillna(vc["daily_vaccinations"].min(), inplace=True)

# %%
vc.groupby(["country"]).min()
# Out:
#                             date  daily_vaccinations  \
# country
# Argentina               1/1/2021                 1.0
# Austria                1/10/2021                 1.0
# Bahrain                 1/1/2021                 1.0
# Belgium                 1/1/2021                 1.0
# Brazil                 1/16/2021                 1.0
# Bulgaria                1/1/2021                 1.0
# Canada                  1/1/2021                 1.0
# Chile                   1/1/2021                 1.0
# China                   1/1/2021                 1.0
# Costa Rica              1/1/2021                 1.0
# Croatia                 1/1/2021                 1.0
# Cyprus                 1/10/2021                 1.0
# Czechia                 1/1/2021                 1.0
# Denmark                 1/1/2021                 1.0
# Ecuador                1/21/2021                 1.0
# England                 1/1/2021                 1.0
# ...
